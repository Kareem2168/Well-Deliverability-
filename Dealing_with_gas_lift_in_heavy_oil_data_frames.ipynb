# %% [markdown]
# <a href="https://colab.research.google.com/github/Kareem2168/Kareem2168/blob/main/Dealing_with_gas_lift_in_heavy_oil_data_frames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import plotly.express as px 
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4f7f9509-77ee-4717-b505-bc280993e828" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f7f9509-77ee-4717-b505-bc280993e828">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Book.xlsx to Book.xlsx
# ...

# %%
df=pd.read_excel('Book.xlsx', sheet_name='GAS LIFT')
df
# Out:
#                              gas lift with gor  Unnamed: 1 Unnamed: 2  \
# 0                                          NaN         NaN        NaN
# 1                                          NaN         NaN        NaN
# 2                                          NaN         NaN        NaN
# 3                                          NaN         NaN        NaN
# 4                                          NaN         NaN        NaN
# ..                                         ...         ...        ...
# 66                                         NaN         NaN        NaN
# 67  IDIAMETER=1 ins Flowrate=236.5574 sbbl/day         NaN   38.70944
# 68  IDIAMETER=3 ins Flowrate=6088.028 sbbl/day         NaN   3845.941
# 69  IDIAMETER=4 ins Flowrate=6823.339 sbbl/day         NaN   6814.358
# 70   IDIAMETER=5 ins Flowrate=7068.77 sbbl/day         NaN   9613.667
#
#    Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# ...

# %%
df
# Out:
#                              gas lift with gor Unnamed: 2 Unnamed: 3  \
# 0                                          NaN        NaN        NaN
# 1                                          NaN        NaN        NaN
# 2                                          NaN        NaN        NaN
# 3                                          NaN        NaN        NaN
# 4                                          NaN        NaN        NaN
# ..                                         ...        ...        ...
# 66                                         NaN        NaN        NaN
# 67  IDIAMETER=1 ins Flowrate=236.5574 sbbl/day   38.70944   3695.315
# 68  IDIAMETER=3 ins Flowrate=6088.028 sbbl/day   3845.941   3531.362
# 69  IDIAMETER=4 ins Flowrate=6823.339 sbbl/day   6814.358   3405.877
# 70   IDIAMETER=5 ins Flowrate=7068.77 sbbl/day   9613.667   3289.305
#
#    Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# ...

# %%
df_gor=df.iloc[43:46]

# %%
df_gor.rename({'Unnamed: 2':'Q_Well1', 'Unnamed: 3':'P_Well1','Unnamed: 5' :'Q_Well2','Unnamed: 6':'P_Well2' }, axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_gor
# Out:
#                               gas lift with gor   Q_Well1   P_Well1   Q_Well2  \
# 43  GOR=200 scf/sbbl Flowrate=2470.814 sbbl/day  1334.762  3615.327  1532.192
# 44  GOR=100 scf/sbbl Flowrate=1270.814 sbbl/day  1152.537  3549.448  1326.664
# 45   GOR=50 scf/sbbl Flowrate=780.9347 sbbl/day  993.0093  3486.274  1142.009
#
#      P_Well2  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 43  3603.329         NaN         NaN         NaN          NaN          NaN
# 44  3527.527         NaN         NaN         NaN          NaN          NaN
# 45  3455.565         NaN         NaN         NaN          NaN          NaN
#
#     Unnamed: 12 Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 43          NaN         NaN          NaN          NaN          NaN
# 44          NaN         NaN          NaN          NaN          NaN
# 45          NaN         NaN          NaN          NaN          NaN
#
#     Unnamed: 17  Unnamed: 18
# 43          NaN          NaN
# ...

# %%
#I dropped all the unneeded columns

# %%
df_gor
# Out:
#                               gas lift with gor   Q_Well1   P_Well1   Q_Well2  \
# 43  GOR=200 scf/sbbl Flowrate=2470.814 sbbl/day  1334.762  3615.327  1532.192
# 44  GOR=100 scf/sbbl Flowrate=1270.814 sbbl/day  1152.537  3549.448  1326.664
# 45   GOR=50 scf/sbbl Flowrate=780.9347 sbbl/day  993.0093  3486.274  1142.009
#
#      P_Well2
# 43  3603.329
# 44  3527.527
# 45  3455.565

# %%
df_gor.pivot(index='gas lift with gor', columns='Q_Well1', values='P_Well1')

# %%
plt.scatter(df_gor['Q_Well1'], df_gor['P_Well1'],label= df_gor['gas lift with gor'])
plt.legend()

# %%
px.scatter(x=df_gor['Q_Well1'], y=df_gor['P_Well1'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
